# %%
import pandas as pd
import glob

folder_path = "/Users/sunvidaneja/Downloads/productDownload_2023-04-29T220900"

csv_files = glob.glob(folder_path + "/ACSDP5Y*-Data.csv")

data_frames = []
for file_path in csv_files:
    df = pd.read_csv(file_path, header=1)
    year = file_path.split('/')[-1][7:11]
    df['Year'] = year
    data_frames.append(df)

combined_df = pd.concat(data_frames, ignore_index=True)
combined_df['Geographic Area Name'] = combined_df['Geographic Area Name'].str.replace('ZCTA5 ', '').astype(float)
# Out:
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (3,4,219,220,459,460,516,517,523,524,563,564) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (3,4,219,220,459,460,515,516,524,525,564,565) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (75,76,84,85,99,100,104,105,108,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (76,77,84,85,99,100,104,105,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (76,77,84,85,99,100,103,104,108,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (75,76,83,84,99,100,103,104,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (75,76,83,84,100,101,103,104,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (139,140,171,172,179,180,187,188) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (3,4,140,141,172,173,220,221,460,461,516,517,524,525,563,564) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (27,28,139,140,163,164,171,172,179,180,188,189,196,197,203,204,212,213) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)
# /var/folders/2_/1r7kvrgj32vcvy8llqd70dj00000gn/T/ipykernel_96386/3144156747.py:10: DtypeWarning: Columns (3,4,220,221,460,461,516,517,524,525,563,564) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)

# %%
combined_df['Year'].value_counts()
# Out:
# 2021    2705
# 2017    2652
# 2019    2652
# 2020    2652
# 2018    2652
# 2016    2612
# 2015    2612
# 2014    2588
# 2012    2588
# 2013    2588
# 2011    2588
# Name: Year, dtype: int64

# %%
combined_df.shape
# Out:
# (28889, 1690)

# %%
combined_df
# Out:
#             Geography  Geographic Area Name  \
# 0      8600000US73949               73949.0
# 1      8600000US75001               75001.0
# 2      8600000US75002               75002.0
# 3      8600000US75006               75006.0
# 4      8600000US75007               75007.0
# ...               ...                   ...
# 28884  8600000US79938               79938.0
# 28885  8600000US79942               79942.0
# 28886  8600000US88063               88063.0
# 28887  8600000US88220               88220.0
# 28888  8600000US88430               88430.0
#
#        Estimate!!SEX AND AGE!!Total population  \
# 0                                       1439.0
# 1                                      13766.0
# 2                                      66679.0
# 3                                      48583.0
# 4                                      52541.0
# ...                                        ...
# 28884                                  51367.0
# 28885                                      0.0
# 28886                                  12748.0
# 28887                                  33973.0
# 28888                                    231.0
#
#       Margin of Error!!SEX AND AGE!!Total population  \
# 0                                                202
# 1                                                268
# 2                                               1183
# 3                                                469
# 4                                               1018
# ...                                              ...
# 28884                                           2206
# 28885                                             95
# 28886                                            412
# 28887                                            663
# 28888                                            123
#
#       Annotation of Margin of Error!!SEX AND AGE!!Total population  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Annotation of Estimate!!SEX AND AGE!!Total population  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Percent!!SEX AND AGE!!Total population  \
# 0                                      1439.0
# 1                                     13766.0
# 2                                     66679.0
# 3                                     48583.0
# 4                                     52541.0
# ...                                       ...
# 28884                                 51367.0
# 28885                                     0.0
# 28886                                 12748.0
# 28887                                 33973.0
# 28888                                   231.0
#
#        Annotation of Percent!!SEX AND AGE!!Total population  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#       Percent Margin of Error!!SEX AND AGE!!Total population  \
# 0                                                    (X)
# 1                                                    (X)
# 2                                                    (X)
# 3                                                    (X)
# 4                                                    (X)
# ...                                                  ...
# 28884                                                (X)
# 28885                                                (X)
# 28886                                                (X)
# 28887                                                (X)
# 28888                                                (X)
#
#       Annotation of Percent Margin of Error!!SEX AND AGE!!Total population  \
# 0                                                    (X)
# 1                                                    (X)
# 2                                                    (X)
# 3                                                    (X)
# 4                                                    (X)
# ...                                                  ...
# 28884                                                (X)
# 28885                                                (X)
# 28886                                                (X)
# 28887                                                (X)
# 28888                                                (X)
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 28884  ...
# 28885  ...
# 28886  ...
# 28887  ...
# 28888  ...
#
#        Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                0.3
# 28885                                                 **
# 28886                                                0.3
# 28887                                                0.2
# 28888                                               13.1
#
#        Annotation of Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                 **
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                              253.0
# 28885                                                0.0
# 28886                                                0.0
# 28887                                              684.0
# 28888                                                0.0
#
#        Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                              127.0
# 28885                                               95.0
# 28886                                               89.0
# 28887                                              206.0
# 28888                                               89.0
#
#       Annotation of Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#       Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#       Percent!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                0.5
# 28885                                                  -
# 28886                                                0.0
# 28887                                                2.0
# 28888                                                0.0
#
#       Annotation of Percent!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                  -
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                0.2
# 28885                                                 **
# 28886                                                0.3
# 28887                                                0.6
# 28888                                               13.1
#
#        Annotation of Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                 **
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
# [28889 rows x 1690 columns]

# %%
# Convert string columns to numeric types and drop columns that cannot be converted
for col in combined_df.select_dtypes(include='object').columns:
    try:
        combined_df[col] = pd.to_numeric(combined_df[col])
    except ValueError:
        combined_df = combined_df.drop(col, axis=1)

# %%
combined_df.shape
# Out:
# (28889, 681)

# %%
combined_df['Year']
# Out:
# 0        2014
# 1        2014
# 2        2014
# 3        2014
# 4        2014
#          ...
# 28884    2011
# 28885    2011
# 28886    2011
# 28887    2011
# 28888    2011
# Name: Year, Length: 28889, dtype: int64

# %%
combined_df = combined_df.loc[:, ~combined_df.columns.str.contains('Margin of Error!!')]

# %%
# Find duplicates based on 'Year' and 'Zip Code'
duplicates_mask = combined_df.duplicated(subset=['Year', 'Geographic Area Name'], keep=False)

# Filter out duplicates
combined_df = combined_df[~duplicates_mask]

# %%
combined_df.shape
# Out:
# (21382, 383)

# %%
# Calculate percentage change
pct_change_df = combined_df.groupby('Geographic Area Name').apply(lambda x: x.drop(['Year', 'Geographic Area Name'], axis=1).pct_change() * 100)
pct_change_df['Year'] = combined_df['Year']
pct_change_df['Geographic Area Name'] = combined_df['Geographic Area Name']


# Replace infinite values with NaN
pct_change_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
pct_change_df
# Out:
#        Estimate!!SEX AND AGE!!Total population  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 28884                               -25.533488
# 28885                              -100.000000
# 28886                                -5.633282
# 28887                                -3.598082
# 28888                               234.782609
#
#        Annotation of Estimate!!SEX AND AGE!!Total population  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Percent!!SEX AND AGE!!Total population  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 28884                              -25.533488
# 28885                             -100.000000
# 28886                               -5.633282
# 28887                               -3.598082
# 28888                              234.782609
#
#        Annotation of Percent!!SEX AND AGE!!Total population  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!SEX AND AGE!!Total population!!Male  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 28884                                            0.0
# 28885                                            0.0
# 28886                                            0.0
# 28887                                            0.0
# 28888                                            0.0
#
#        Annotation of Estimate!!SEX AND AGE!!Total population!!Male  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 28884                                              0.0
# 28885                                              0.0
# 28886                                              0.0
# 28887                                              0.0
# 28888                                              0.0
#
#        Annotation of Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!SEX AND AGE!!Under 5 years  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 28884                            -32.228336
# 28885                                   NaN
# 28886                             40.595010
# 28887                              8.005427
# 28888                                   NaN
#
#        Annotation of Estimate!!SEX AND AGE!!Under 5 years  ...  \
# 0                                                    NaN   ...
# 1                                                    NaN   ...
# 2                                                    NaN   ...
# 3                                                    NaN   ...
# 4                                                    NaN   ...
# ...                                                  ...   ...
# 28884                                                NaN   ...
# 28885                                                NaN   ...
# 28886                                                NaN   ...
# 28887                                                NaN   ...
# 28888                                                NaN   ...
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Some other race alone  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                         -32.608696
# 28885                                                NaN
# 28886                                                NaN
# 28887                                          12.195122
# 28888                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Some other race alone  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                         -22.587269
# 28885                                                NaN
# 28886                                                NaN
# 28887                                          -4.149933
# 28888                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                          -5.343511
# 28885                                                NaN
# 28886                                                NaN
# 28887                                         -13.513514
# 28888                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                         -28.932584
# 28885                                                NaN
# 28886                                                NaN
# 28887                                          -3.661972
# 28888                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28884                                                NaN
# 28885                                                NaN
# 28886                                                NaN
# 28887                                                NaN
# 28888                                                NaN
#
#        Year  Geographic Area Name
# 0      2014               73949.0
# 1      2014               75001.0
# 2      2014               75002.0
# 3      2014               75006.0
# 4      2014               75007.0
# ...     ...                   ...
# 28884  2011               79938.0
# 28885  2011               79942.0
# 28886  2011               88063.0
# 28887  2011               88220.0
# 28888  2011               88430.0
#
# [21382 rows x 383 columns]

# %%
# Calculate percentage of missing values in each row
missing_percentages = pct_change_df.isna().sum(axis=1) / len(pct_change_df.columns) * 100

# Print the missing percentages for each row
print(missing_percentages.max)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0        99.477807
# 1        99.477807
# 2        99.477807
# 3        99.477807
# 4        99.477807
#            ...
# 28884    53.263708
# 28885    87.206266
# 28886    66.318538
# 28887    55.091384
# 28888    77.545692
# Length: 21382, dtype: float64>

# %%
pct_change_df = pct_change_df[missing_percentages <= 90]

# %%
pct_change_df.shape
# Out:
# (18955, 383)

# %% [markdown]
# # PCA

# %%
acs = pct_change_df

# %%
acs = acs.rename(columns={'Geographic Area Name': 'Zip Code'})

# %%
acs.shape
# Out:
# (18955, 383)

# %%
acs = acs.sort_values('Year')

# %%
# # Find rows that are duplicated on 'Year' and 'Zip Code'
# mask = acs.duplicated(subset=['Year', 'Zip Code'], keep=False)

# # Create a DataFrame of duplicated rows
# duplicated_df = acs.loc[mask, :]

# # Calculate percentage of missing values in each row
# missing_percentages = duplicated_df.isna().sum(axis=1) / len(duplicated_df.columns) * 100

# # Print the missing percentages for each row
# print(missing_percentages.mean())

# %%
# # Find duplicates based on 'Year' and 'Zip Code'
# duplicates_mask = acs.duplicated(subset=['Year', 'Zip Code'], keep=False)

# # Filter out duplicates
# acs = acs[~duplicates_mask]

# %%
acs.shape
# Out:
# (18955, 383)

# %%
acs
# Out:
#        Estimate!!SEX AND AGE!!Total population  \
# 28888                               234.782609
# 27584                               -17.250367
# 27585                                 3.455890
# 27586                                12.781376
# 27587                                -9.818758
# ...                                        ...
# 14526                                -5.513602
# 14525                               -32.677165
# 14524                                10.772834
# 14522                                -5.572597
# 13985                                21.938326
#
#        Annotation of Estimate!!SEX AND AGE!!Total population  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Percent!!SEX AND AGE!!Total population  \
# 28888                              234.782609
# 27584                              -17.250367
# 27585                                3.455890
# 27586                               12.781376
# 27587                               -9.818758
# ...                                       ...
# 14526                               -5.513602
# 14525                              -32.677165
# 14524                               10.772834
# 14522                               -5.572597
# 13985                               21.938326
#
#        Annotation of Percent!!SEX AND AGE!!Total population  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Estimate!!SEX AND AGE!!Total population!!Male  \
# 28888                                       0.000000
# 27584                                       0.000000
# 27585                                       0.000000
# 27586                                       0.000000
# 27587                                       0.000000
# ...                                              ...
# 14526                                      -3.401609
# 14525                                     -31.617647
# 14524                                       8.037094
# 14522                                      -6.517190
# 13985                                      24.238026
#
#        Annotation of Estimate!!SEX AND AGE!!Total population!!Male  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Estimate!!SEX AND AGE!!Total population!!Female  \
# 28888                                         0.000000
# 27584                                         0.000000
# 27585                                         0.000000
# 27586                                         0.000000
# 27587                                         0.000000
# ...                                                ...
# 14526                                        -7.604563
# 14525                                       -33.898305
# 14524                                        13.564669
# 14522                                        -4.867158
# 13985                                        18.385650
#
#        Annotation of Estimate!!SEX AND AGE!!Total population!!Female  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Estimate!!SEX AND AGE!!Under 5 years  \
# 28888                                   NaN
# 27584                            -14.047252
# 27585                              1.688671
# 27586                              0.800178
# 27587                             45.430945
# ...                                     ...
# 14526                              0.000000
# 14525                              0.000000
# 14524                              0.000000
# 14522                              0.000000
# 13985                              0.000000
#
#        Annotation of Estimate!!SEX AND AGE!!Under 5 years  ...  \
# 28888                                                NaN   ...
# 27584                                                NaN   ...
# 27585                                                NaN   ...
# 27586                                                NaN   ...
# 27587                                                NaN   ...
# ...                                                  ...   ...
# 14526                                                NaN   ...
# 14525                                                NaN   ...
# 14524                                                NaN   ...
# 14522                                                NaN   ...
# 13985                                                NaN   ...
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Some other race alone  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                          -6.896552
# 27587                                         100.000000
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Some other race alone  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races  \
# 28888                                                NaN
# 27584                                           1.017442
# 27585                                          -7.385079
# 27586                                         -20.341394
# 27587                                         -11.867365
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 28888                                                NaN
# 27584                                         -11.267606
# 27585                                          -5.882353
# 27586                                                NaN
# 27587                                         -42.857143
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 28888                                                NaN
# 27584                                           1.455093
# 27585                                          -7.424594
# 27586                                         -21.408250
# 27587                                         -11.484099
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Annotation of Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races  \
# 28888                                                NaN
# 27584                                                NaN
# 27585                                                NaN
# 27586                                                NaN
# 27587                                                NaN
# ...                                                  ...
# 14526                                                NaN
# 14525                                                NaN
# 14524                                                NaN
# 14522                                                NaN
# 13985                                                NaN
#
#        Year  Zip Code
# 28888  2011   88430.0
# 27584  2011   76542.0
# 27585  2011   76543.0
# 27586  2011   76544.0
# 27587  2011   76548.0
# ...     ...       ...
# 14526  2021   76667.0
# 14525  2021   76666.0
# 14524  2021   76665.0
# 14522  2021   76661.0
# 13985  2021   75420.0
#
# [18955 rows x 383 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# # Standardize the PCA-transformed data
# scaler = MinMaxScaler()
# acs_pca_scaled = scaler.fit_transform(acs)

# %%
# Calculate percentage of missing values in each column
missing_percentages = acs.isna().sum() / len(acs)

# Get column names where missing percentage is more than 80%
columns_to_drop = missing_percentages[missing_percentages > 0.8].index

# Drop columns with more than 80% missing values
acs = acs.drop(columns_to_drop, axis=1)

from sklearn.decomposition import PCA
import pandas as pd

# Filter out non-numeric columns
acs = acs.select_dtypes(include=[float, int])

from sklearn.impute import SimpleImputer

# Impute missing values with mean imputation
imputer = SimpleImputer(strategy='mean')
acs_imputed = pd.DataFrame(imputer.fit_transform(acs), columns=acs.columns)

# Standardize the PCA-transformed data
scaler = MinMaxScaler()
acs_pca_scaled = scaler.fit_transform(acs_imputed)

# Perform PCA on the data
n_components = 10
pca = PCA(n_components=n_components)
pca.fit(acs_pca_scaled)

# Transform the data into the new reduced-dimensional space
acs_transformed = pca.transform(acs_pca_scaled)

# Create a new DataFrame with the transformed data
acs_pca = pd.DataFrame(data=acs_transformed, columns=[f'PC{i}' for i in range(1, n_components+1)])

# %%
acs_pca
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      0.523150  0.766194  0.164807  0.016885  0.005548 -0.004045  0.213682
# 1      0.520234 -0.060028 -0.053050  0.001372  0.001612  0.000417  0.004411
# 2      0.520453 -0.059169 -0.008736  0.001511  0.001048  0.001140  0.012973
# 3      0.519283 -0.057277  0.169327 -0.011871 -0.004314  0.002471 -0.116486
# 4      0.520352 -0.059114 -0.026670  0.000421  0.001067  0.000701 -0.002612
# ...         ...       ...       ...       ...       ...       ...       ...
# 18950 -0.479340 -0.050366 -0.004812 -0.010411  0.002294 -0.005099  0.002776
# 18951 -0.478487 -0.050901 -0.005461 -0.035771  0.004893 -0.036609  0.003645
# 18952 -0.480407 -0.050220 -0.004641  0.007963  0.005866  0.001735  0.002011
# 18953 -0.479908 -0.050561 -0.004991 -0.014452  0.008064 -0.025156  0.003437
# 18954 -0.479375 -0.136329 -0.002775 -0.003121  0.000949  0.002400  0.003207
#
#             PC8       PC9      PC10
# 0     -0.003381  0.005498  0.008814
# 1     -0.021099 -0.009517 -0.000939
# 2     -0.015847 -0.006862 -0.002337
# 3     -0.030332 -0.009271  0.004864
# 4     -0.017315 -0.007770 -0.001403
# ...         ...       ...       ...
# 18950  0.004262 -0.007261  0.011198
# 18951  0.003352 -0.003971 -0.035468
# 18952  0.000893  0.000831  0.050937
# 18953  0.002831 -0.005768  0.007040
# 18954  0.002686 -0.001773 -0.004628
#
# [18955 rows x 10 columns]

# %%
acs_imputed['Zip Code']
# Out:
# 0        88430.0
# 1        76542.0
# 2        76543.0
# 3        76544.0
# 4        76548.0
#           ...
# 18950    76667.0
# 18951    76666.0
# 18952    76665.0
# 18953    76661.0
# 18954    75420.0
# Name: Zip Code, Length: 18955, dtype: float64

# %%
acs_pca_with_year = pd.concat([acs_pca, acs_imputed['Year'], acs_imputed['Zip Code']], axis=1)

# %%
acs_pca_with_year
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      0.523150  0.766194  0.164807  0.016885  0.005548 -0.004045  0.213682
# 1      0.520234 -0.060028 -0.053050  0.001372  0.001612  0.000417  0.004411
# 2      0.520453 -0.059169 -0.008736  0.001511  0.001048  0.001140  0.012973
# 3      0.519283 -0.057277  0.169327 -0.011871 -0.004314  0.002471 -0.116486
# 4      0.520352 -0.059114 -0.026670  0.000421  0.001067  0.000701 -0.002612
# ...         ...       ...       ...       ...       ...       ...       ...
# 18950 -0.479340 -0.050366 -0.004812 -0.010411  0.002294 -0.005099  0.002776
# 18951 -0.478487 -0.050901 -0.005461 -0.035771  0.004893 -0.036609  0.003645
# 18952 -0.480407 -0.050220 -0.004641  0.007963  0.005866  0.001735  0.002011
# 18953 -0.479908 -0.050561 -0.004991 -0.014452  0.008064 -0.025156  0.003437
# 18954 -0.479375 -0.136329 -0.002775 -0.003121  0.000949  0.002400  0.003207
#
#             PC8       PC9      PC10    Year  Zip Code
# 0     -0.003381  0.005498  0.008814  2011.0   88430.0
# 1     -0.021099 -0.009517 -0.000939  2011.0   76542.0
# 2     -0.015847 -0.006862 -0.002337  2011.0   76543.0
# 3     -0.030332 -0.009271  0.004864  2011.0   76544.0
# 4     -0.017315 -0.007770 -0.001403  2011.0   76548.0
# ...         ...       ...       ...     ...       ...
# 18950  0.004262 -0.007261  0.011198  2021.0   76667.0
# 18951  0.003352 -0.003971 -0.035468  2021.0   76666.0
# 18952  0.000893  0.000831  0.050937  2021.0   76665.0
# 18953  0.002831 -0.005768  0.007040  2021.0   76661.0
# 18954  0.002686 -0.001773 -0.004628  2021.0   75420.0
#
# [18955 rows x 12 columns]

# %%
acs_pca_with_year.to_csv('acs_pca_with_year_ratechange.csv')

# %%
# Get the explained variance ratios
explained_variances = pca.explained_variance_ratio_
print('Explained variance ratios:', explained_variances)
# Out:
# Explained variance ratios: [0.70539142 0.06857293 0.0175875  0.0129464  0.01169019 0.00999782
#  0.00881961 0.00562099 0.00550223 0.00495475]

# %%
import matplotlib.pyplot as plt

# Get the explained variance ratios
explained_variances = pca.explained_variance_ratio_

# Plot the explained variance ratios as a bar plot
fig, ax = plt.subplots()
ax.bar(range(len(explained_variances)), explained_variances)

# Set the x-axis labels to PC1, PC2, etc.
ax.set_xticks(range(len(explained_variances)))
ax.set_xticklabels([f'PC{i}' for i in range(1, len(explained_variances)+1)])

# Set the y-axis label
ax.set_xlabel('Principal Component')
ax.set_ylabel('Explained Variance Ratio')
ax.set_title('Explained Variance Ratios of PCA Components')

# Show the plot
plt.show()

# %%
# Get the loadings
loadings = pd.DataFrame(pca.components_.T, columns=[f'PC{i}' for i in range(1, n_components+1)], index=acs.columns)
loadings
# Out:
#                                                          PC1       PC2  \
# Estimate!!SEX AND AGE!!Total population            -0.000384  0.000304
# Percent!!SEX AND AGE!!Total population             -0.000474  0.000452
# Estimate!!SEX AND AGE!!Total population!!Male      -0.000508  0.000015
# Estimate!!SEX AND AGE!!Total population!!Female    -0.000358  0.000194
# Estimate!!SEX AND AGE!!Under 5 years                0.004153  0.002258
# ...                                                      ...       ...
# Estimate!!RACE!!One race.1                          0.000260 -0.000090
# Estimate!!RACE!!White                              -0.000017 -0.000341
# Estimate!!HISPANIC OR LATINO AND RACE!!Not Hisp...  0.000333  0.000420
# Year                                               -0.999616  0.000140
# Zip Code                                            0.000129  0.999772
#
#                                                          PC3       PC4  \
# Estimate!!SEX AND AGE!!Total population             0.018417  0.147993
# Percent!!SEX AND AGE!!Total population              0.021033  0.144134
# Estimate!!SEX AND AGE!!Total population!!Male       0.005437  0.145604
# Estimate!!SEX AND AGE!!Total population!!Female     0.004288  0.024416
# Estimate!!SEX AND AGE!!Under 5 years                0.026650  0.002740
# ...                                                      ...       ...
# Estimate!!RACE!!One race.1                          0.021709  0.003860
# Estimate!!RACE!!White                               0.018822  0.002745
# Estimate!!HISPANIC OR LATINO AND RACE!!Not Hisp...  0.018707  0.003085
# Year                                               -0.001455 -0.009495
# Zip Code                                           -0.012968 -0.002816
#
#                                                          PC5       PC6  \
# Estimate!!SEX AND AGE!!Total population             0.062909 -0.043628
# Percent!!SEX AND AGE!!Total population              0.067487 -0.044147
# Estimate!!SEX AND AGE!!Total population!!Male       0.063746 -0.045267
# Estimate!!SEX AND AGE!!Total population!!Female    -0.010872  0.033895
# Estimate!!SEX AND AGE!!Under 5 years                0.000399  0.001222
# ...                                                      ...       ...
# Estimate!!RACE!!One race.1                          0.000915  0.000840
# Estimate!!RACE!!White                               0.000617  0.000665
# Estimate!!HISPANIC OR LATINO AND RACE!!Not Hisp...  0.000633  0.000789
# Year                                                0.001352 -0.005591
# Zip Code                                           -0.001177 -0.006923
#
#                                                          PC7       PC8  \
# Estimate!!SEX AND AGE!!Total population             0.007704 -0.000141
# Percent!!SEX AND AGE!!Total population              0.007786  0.000625
# Estimate!!SEX AND AGE!!Total population!!Male      -0.011296  0.000029
# Estimate!!SEX AND AGE!!Total population!!Female     0.002158  0.000301
# Estimate!!SEX AND AGE!!Under 5 years                0.040475  0.039217
# ...                                                      ...       ...
# Estimate!!RACE!!One race.1                          0.071583 -0.000585
# Estimate!!RACE!!White                               0.053836 -0.004896
# Estimate!!HISPANIC OR LATINO AND RACE!!Not Hisp...  0.057140 -0.003432
# Year                                                0.005066  0.014146
# Zip Code                                           -0.002470 -0.006291
#
#                                                          PC9      PC10
# Estimate!!SEX AND AGE!!Total population            -0.000503 -0.007186
# Percent!!SEX AND AGE!!Total population             -0.000702 -0.007184
# Estimate!!SEX AND AGE!!Total population!!Male      -0.000379 -0.006935
# Estimate!!SEX AND AGE!!Total population!!Female     0.000768 -0.000540
# Estimate!!SEX AND AGE!!Under 5 years                0.012439  0.007571
# ...                                                      ...       ...
# Estimate!!RACE!!One race.1                          0.004449  0.007306
# Estimate!!RACE!!White                               0.002037  0.005156
# Estimate!!HISPANIC OR LATINO AND RACE!!Not Hisp...  0.002890  0.006571
# Year                                               -0.001768 -0.008600
# Zip Code                                            0.000085 -0.000303
#
# [152 rows x 10 columns]

# %%
# Get the loadings matrix
loadings = pca.components_

# Get the loadings for PC1
loadings_pc1 = loadings[0]

# Get the indices of the features with the highest loadings in PC1
idx_max_loadings = loadings_pc1.argsort()[::-1]

# Get the names of the columns with the highest loadings in PC1
cols_max_loadings = acs.columns[idx_max_loadings]

# Print the column names and their corresponding loadings
for col, loading in zip(cols_max_loadings, loadings_pc1[idx_max_loadings]):
    print(f'{col}: {loading}')
# Out:
# Estimate!!RACE!!One race!!Some other race: 0.011971498113517956
# Estimate!!RACE!!One race!!American Indian and Alaska Native: 0.006969339011608468
# Estimate!!SEX AND AGE!!45 to 54 years: 0.004509104778005946
# Estimate!!SEX AND AGE!!Under 5 years: 0.004152972951003583
# Estimate!!SEX AND AGE!!35 to 44 years: 0.003935550199866857
# Estimate!!SEX AND AGE!!85 years and over: 0.0032542064296251145
# Estimate!!RACE!!Two or more races!!White and American Indian and Alaska Native: 0.003220068930579626
# Estimate!!SEX AND AGE!!75 to 84 years: 0.002947330446564353
# Estimate!!RACE!!One race!!Black or African American: 0.0028128840158813204
# Estimate!!SEX AND AGE!!5 to 9 years: 0.0025464996747153646
# Estimate!!SEX AND AGE!!20 to 24 years: 0.0025297134408745797
# Estimate!!RACE!!Two or more races!!White and Black or African American: 0.0021349911011839836
# Estimate!!SEX AND AGE!!55 to 59 years: 0.0020768506834479106
# Estimate!!SEX AND AGE!!10 to 14 years: 0.001989576154063527
# Estimate!!RACE!!One race!!Asian!!Asian Indian: 0.001760199411068879
# Estimate!!SEX AND AGE!!15 to 19 years: 0.0015676000123974487
# Estimate!!SEX AND AGE!!25 to 34 years: 0.0015119010437062543
# Estimate!!RACE!!One race!!Asian!!Korean: 0.001494033904792933
# Estimate!!RACE!!One race!!Asian!!Japanese: 0.0014222777746488355
# Estimate!!RACE!!Two or more races: 0.0013885468905840438
# Estimate!!RACE!!One race!!Asian!!Filipino: 0.001364895113459251
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!Some other race: 0.0012787363815875623
# Estimate!!RACE!!One race!!Asian: 0.0011490554672860434
# Estimate!!RACE!!One race!!Asian!!Other Asian: 0.0010370110479466421
# Estimate!!RACE!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping: 0.0010192587867850981
# Estimate!!RACE!!One race!!Asian!!Chinese: 0.0009140045572689143
# Estimate!!SEX AND AGE!!60 to 64 years: 0.0008873979537770947
# Estimate!!RACE!!One race!!Native Hawaiian and Other Pacific Islander: 0.0008622259217992047
# Estimate!!RACE!!One race: 0.0008046757961579192
# Estimate!!RACE!!One race!!Asian!!Vietnamese: 0.0006983227932434172
# Estimate!!RACE!!Two or more races!!White and Asian: 0.0006908412344021982
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population: 0.000681976946320881
# Percent!!RACE!!Race alone or in combination with one or more other races!!Total population: 0.000681976946320881
# Estimate!!RACE!!One race!!White: 0.0004901289841136845
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!Black or African American: 0.0003639518407245884
# Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino: 0.0003329124667209506
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native: 0.00033238884911497904
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander: 0.0002915886765477887
# Estimate!!RACE!!One race.1: 0.00026009378657174023
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!Asian: 0.00025092857832689867
# Estimate!!SEX AND AGE!!21 years and over: 0.00021790522741794503
# Estimate!!SEX AND AGE!!Female.1: 0.0002045224804134964
# Estimate!!SEX AND AGE!!18 years and over.1: 0.0001930101865381084
# Estimate!!SEX AND AGE!!18 years and over: 0.0001930101865381084
# Percent!!SEX AND AGE!!18 years and over.1: 0.0001930101865381084
# Estimate!!SEX AND AGE!!Male: 0.00017380034392066953
# Estimate!!SEX AND AGE!!Female: 0.00016560630696259616
# Zip Code: 0.00012869276451187595
# Estimate!!SEX AND AGE!!Male.1: 0.00012665997565513334
# Estimate!!SEX AND AGE!!18 years and over!!Male: 8.65197415767964e-05
# Estimate!!SEX AND AGE!!18 years and over!!Female: 6.304241174523128e-05
# Estimate!!RACE!!Race alone or in combination with one or more other races!!Total population!!White: 5.65535139793748e-05
# Estimate!!RACE!!White: -1.6608770167706568e-05
# Estimate!!RACE!!Two or more races!!Black or African American and American Indian and Alaska Native: -8.466494669399545e-05
# Estimate!!SEX AND AGE!!65 years and over!!Female: -0.00020590619632310098
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female: -0.00022319937110498768
# Estimate!!RACE!!Total population!!One race!!White: -0.00031070149366865183
# Percent!!SEX AND AGE!!Total population!!18 years and over.1: -0.00032527164917671095
# Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population: -0.0003266196124555259
# Estimate!!RACE!!Total population!!One race.1: -0.0003350822853927885
# Percent!!Race alone or in combination with one or more other races!!Total population: -0.00035725004729039684
# Estimate!!SEX AND AGE!!Total population!!Female: -0.0003579971755449969
# Estimate!!SEX AND AGE!!Total population!!18 years and over.1: -0.0003829323736930681
# Estimate!!SEX AND AGE!!Total population!!18 years and over: -0.0003829323736930681
# Estimate!!SEX AND AGE!!Total population: -0.0003841096520171834
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population: -0.00038410965201729334
# Estimate!!RACE!!Total population: -0.00038410965201729334
# Estimate!!SEX AND AGE!!Total population!!16 years and over: -0.000384507966352177
# Estimate!!RACE!!Total population!!One race: -0.00038503142902272455
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population: -0.0003877376815024715
# Estimate!!SEX AND AGE!!Total population!!21 years and over: -0.0003951828305891536
# Estimate!!Race alone or in combination with one or more other races!!Total population: -0.000417308815500214
# Estimate!!Race alone or in combination with one or more other races!!Total population!!White: -0.0004283979529414069
# Estimate!!SEX AND AGE!!Total population!!25 to 34 years: -0.00044018850783739783
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male: -0.0004558410009835764
# Estimate!!SEX AND AGE!!Total population!!18 years and over!!Male: -0.00045703211187111937
# Percent!!HISPANIC OR LATINO AND RACE!!Total population: -0.00047446418051073956
# Percent!!SEX AND AGE!!Total population: -0.00047446418051073956
# Percent!!RACE!!Total population: -0.00047446418051073956
# Estimate!!SEX AND AGE!!Total population!!45 to 54 years: -0.0004925109109589867
# Estimate!!SEX AND AGE!!Total population!!Male: -0.0005076850376313784
# Estimate!!Total housing units: -0.0005106223502822671
# Estimate!!SEX AND AGE!!65 years and over!!Male: -0.0005600412037596902
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone: -0.0005826160856382444
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino: -0.0006014685825731492
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!White alone: -0.0007805623902233853
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Mexican: -0.0007816796211388029
# Estimate!!SEX AND AGE!!Total population!!35 to 44 years: -0.0007904836823364788
# Percent Estimate!!SEX AND AGE!!Total population!!18 years and over.1: -0.000816413963094546
# Percent Estimate!!RACE!!Total population: -0.0008402118402579814
# Percent Estimate!!HISPANIC OR LATINO AND RACE!!Total population: -0.0008402118402579814
# Percent Estimate!!Race alone or in combination with one or more other races!!Total population: -0.0008402118402579814
# Percent Estimate!!SEX AND AGE!!Total population: -0.0008402118402579814
# Percent Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population: -0.000842313748914408
# Estimate!!RACE!!Total population!!One race!!Asian!!Japanese: -0.0008606804167607887
# Estimate!!RACE!!Total population!!One race!!Black or African American: -0.0008848005384563992
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping: -0.0008957663063629331
# Estimate!!SEX AND AGE!!Total population!!65 years and over!!Female: -0.0009177569063001506
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Black or African American: -0.0009321553622055664
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Black or African American alone: -0.0009595343976375547
# Estimate!!RACE!!Total population!!One race!!Asian!!Asian Indian: -0.0009765064614555348
# Estimate!!SEX AND AGE!!Total population!!55 to 59 years: -0.0011048870627113187
# Estimate!!SEX AND AGE!!Total population!!75 to 84 years: -0.001129059479565423
# Estimate!!SEX AND AGE!!Total population!!Under 18 years: -0.001178524303890807
# Estimate!!RACE!!Total population!!One race!!Asian!!Other Asian: -0.001201508406374158
# Estimate!!SEX AND AGE!!65 to 74 years: -0.0012145364558245899
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander: -0.0012590758381524072
# Percent Estimate!!SEX AND AGE!!Total population!!65 years and over.1: -0.0013520362318156808
# Estimate!!RACE!!Total population!!One race!!Asian!!Korean: -0.001418826667354294
# Estimate!!Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native: -0.001504969614055381
# Estimate!!SEX AND AGE!!Total population!!5 to 9 years: -0.0015322790798634022
# Estimate!!SEX AND AGE!!Total population!!65 years and over!!Male: -0.0015393705558022447
# Estimate!!SEX AND AGE!!Total population!!85 years and over: -0.0015621336756169375
# Estimate!!RACE!!Total population!!One race!!Asian!!Vietnamese: -0.001631086757314403
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Asian alone: -0.0016361890651030388
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican: -0.0016885121952730962
# Estimate!!SEX AND AGE!!Total population!!15 to 19 years: -0.0017377295830636004
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino: -0.001779064732424511
# Estimate!!SEX AND AGE!!Total population!!18 years and over!!Female: -0.0018366569459348518
# Estimate!!RACE!!Total population!!One race!!Asian!!Chinese: -0.0018370272699116835
# Estimate!!SEX AND AGE!!Total population!!Under 5 years: -0.0019692836275528917
# Estimate!!RACE!!Total population!!One race!!Asian: -0.0020367516533841123
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race): -0.002042025791274162
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban: -0.0021329137291213303
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Asian: -0.0022330309402603487
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race: -0.0024550563110006494
# Percent!!SEX AND AGE!!Total population!!65 years and over.1: -0.0024859767195070416
# Percent!!SEX AND AGE!!65 years and over.1: -0.0024904806123802366
# Estimate!!SEX AND AGE!!65 years and over.1: -0.0024904806123802366
# Estimate!!SEX AND AGE!!65 years and over: -0.0024904806123802366
# Estimate!!RACE!!Total population!!One race!!Some other race: -0.00253086419348156
# Estimate!!RACE!!Total population!!Two or more races!!White and Black or African American: -0.0025506203305532336
# Estimate!!SEX AND AGE!!62 years and over: -0.002815364234620022
# Estimate!!SEX AND AGE!!Total population!!62 years and over: -0.002932883562226824
# Estimate!!RACE!!Total population!!One race!!Asian!!Filipino: -0.0030907561986243883
# Estimate!!SEX AND AGE!!Total population!!65 to 74 years: -0.0031539260835323976
# Estimate!!SEX AND AGE!!Total population!!60 to 64 years: -0.0031596300685238867
# Estimate!!SEX AND AGE!!Total population!!20 to 24 years: -0.003197626377589069
# Estimate!!RACE!!Total population!!Two or more races!!White and American Indian and Alaska Native: -0.003234557443506567
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native: -0.003511346193276739
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!American Indian and Alaska Native alone: -0.0037030631840619336
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or more races: -0.0037712980397622037
# Estimate!!SEX AND AGE!!Total population!!10 to 14 years: -0.004039436804945977
# Estimate!!RACE!!Total population!!Two or more races.1: -0.004101353815918718
# Estimate!!SEX AND AGE!!Total population!!65 years and over.1: -0.004151459563938537
# Estimate!!SEX AND AGE!!Total population!!65 years and over: -0.004151459563938537
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Some other race alone: -0.004241121144654068
# Estimate!!RACE!!Total population!!Two or more races: -0.004492562300973669
# Estimate!!RACE!!Total population!!Two or more races!!White and Asian: -0.005051897583877561
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and Three or more races: -0.005113487516559396
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Some other race: -0.006462986396325799
# Year: -0.9996163698355668

# %%
import matplotlib.pyplot as plt

plt.scatter(acs_pca['PC1'], acs_pca['PC2'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
# Calculate percentage of missing values in each column
missing_percentages = acs.isna().sum() / len(acs)

# Get column names where missing percentage is more than 80%
columns_to_drop = missing_percentages[missing_percentages > 0.8].index

# Drop columns with more than 80% missing values
acs = acs.drop(columns_to_drop, axis=1)

from sklearn.decomposition import PCA
import pandas as pd

# Filter out non-numeric columns
acs = acs.select_dtypes(include=[float, int])

from sklearn.impute import SimpleImputer

# Impute missing values with mean imputation
imputer = SimpleImputer(strategy='mean')
acs_imputed = pd.DataFrame(imputer.fit_transform(acs), columns=acs.columns)

# Standardize the PCA-transformed data
scaler = MinMaxScaler()
acs_pca_scaled = scaler.fit_transform(acs_imputed)

# Perform PCA on the data
n_components = 10
pca = PCA(n_components=n_components)
pca.fit(acs_pca_scaled)

# Transform the data into the new reduced-dimensional space
acs_transformed = pca.transform(acs_pca_scaled)

# Remove outliers
from scipy.spatial.distance import mahalanobis

distances = []
for i in range(acs_transformed.shape[0]):
    dist = mahalanobis(acs_transformed[i], np.mean(acs_transformed, axis=0), np.cov(acs_transformed.T))
    distances.append(dist)

median_distance = np.median(distances)
threshold = 3 * median_distance

acs_pca = pd.DataFrame(data=acs_transformed, columns=[f'PC{i}' for i in range(1, n_components+1)])
acs_pca = acs_pca[distances <= threshold]

# Plot the PCA with PC1 and PC2 color-coded differently
plt.scatter(acs_pca['PC1'], acs_pca['PC2'], c=acs_pca['PC1'], cmap='coolwarm')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot data points with different colors based on PC1 values
ax.scatter(acs_pca['PC1'], acs_pca['PC2'], acs_pca['PC3'], c=acs_pca['PC1'], cmap='viridis')

# Set labels for the axes
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')

plt.show()

# %%
loadings = pca.components_[0]
sorted_loadings = sorted(zip(loadings, acs.columns), reverse=True)
top_features = [feature for loading, feature in sorted_loadings[:20]]
print(top_features)
# Out:
# ['Estimate!!RACE!!One race!!Some other race', 'Estimate!!RACE!!One race!!American Indian and Alaska Native', 'Estimate!!SEX AND AGE!!45 to 54 years', 'Estimate!!SEX AND AGE!!Under 5 years', 'Estimate!!SEX AND AGE!!35 to 44 years', 'Estimate!!SEX AND AGE!!85 years and over', 'Estimate!!RACE!!Two or more races!!White and American Indian and Alaska Native', 'Estimate!!SEX AND AGE!!75 to 84 years', 'Estimate!!RACE!!One race!!Black or African American', 'Estimate!!SEX AND AGE!!5 to 9 years', 'Estimate!!SEX AND AGE!!20 to 24 years', 'Estimate!!RACE!!Two or more races!!White and Black or African American', 'Estimate!!SEX AND AGE!!55 to 59 years', 'Estimate!!SEX AND AGE!!10 to 14 years', 'Estimate!!RACE!!One race!!Asian!!Asian Indian', 'Estimate!!SEX AND AGE!!15 to 19 years', 'Estimate!!SEX AND AGE!!25 to 34 years', 'Estimate!!RACE!!One race!!Asian!!Korean', 'Estimate!!RACE!!One race!!Asian!!Japanese', 'Estimate!!RACE!!Two or more races']

# %%
import matplotlib.pyplot as plt

loadings = pca.components_[0]
sorted_loadings = sorted(zip(loadings, acs.columns), reverse=True)
top_features = [feature for loading, feature in sorted_loadings[:10]]

fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(top_features, [loading for loading, feature in sorted_loadings[:10]])
ax.set_xlabel('Loadings')
ax.set_title('Top 20 Features in PC1')
plt.show()

# %% [markdown]
# # TSNE

# %%
from sklearn.manifold import TSNE

# Create a t-SNE object with two components
tsne = TSNE(n_components=2)

# Fit and transform the PCA-transformed data with t-SNE
acs_tsne = tsne.fit_transform(acs_transformed)

# Create a new DataFrame with the t-SNE transformed data
acs_tsne_df = pd.DataFrame(data=acs_tsne, columns=['tsne1', 'tsne2'])

# Plot the t-SNE transformed data with PC1 and PC2 as color codes
sns.scatterplot(data=acs_tsne_df, x='tsne1', y='tsne2', hue=acs_pca['PC1'], palette='coolwarm')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()
# Out:
# /Users/sunvidaneja/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/sunvidaneja/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# # Singular Value Decomposition

# %%
from sklearn.decomposition import TruncatedSVD

# Perform SVD on the data
svd = TruncatedSVD(n_components=10)
svd.fit(acs_imputed)

# Transform the data into the new reduced-dimensional space
acs_transformed_svd = svd.transform(acs_imputed)

# Create a new DataFrame with the transformed data
acs_svd = pd.DataFrame(data=acs_transformed_svd, columns=[f'SVD{i}' for i in range(1, n_components+1)])

# %%
acs_svd
# Out:
#               SVD1          SVD2          SVD3          SVD4          SVD5  \
# 0     8.735375e+06  36522.730104  67755.146841  22370.510064 -15751.669599
# 1     4.319674e+03    -92.243197   -694.240728   -446.374639    139.406440
# 2     8.459997e+01     -9.938480    -86.228208    -81.320770     12.637140
# 3     6.684486e+04  -7646.768783   7429.150036  -6938.646603   2334.576709
# 4     2.416950e+05 -24506.550102 -15143.338421   5949.375250  -1277.878301
# ...            ...           ...           ...           ...           ...
# 1988  8.753537e+04  -4662.463453  -5961.045052  -1060.349876   1298.963585
# 1989  6.012893e+04   1797.120101  -5630.762723  -4665.452489    572.689979
# 1990  3.536587e+05   3395.252798 -15570.935660  -5340.113922   -782.094654
# 1991  2.743678e+05   -933.987671 -28812.082963  10918.739585   4962.513562
# 1992  5.514326e+02    -12.617751   -158.524768   -210.471923     62.189447
#
#              SVD6         SVD7          SVD8         SVD9        SVD10
# 0     -819.183101   -76.538405   -532.726173    -6.734537  -966.874607
# 1      -60.010556   -62.550475    -42.187766   -28.140993   -47.025727
# 2        1.940980   -22.549279    -19.696085     3.964980   -12.905912
# 3      793.438102 -1384.971213    116.477020   624.909836  -146.217572
# 4     4279.432825  3702.271058  -1663.384547 -2300.368555   135.957453
# ...           ...          ...           ...          ...          ...
# 1988 -1384.116801   561.055610   2251.939420  3359.499086   457.658181
# 1989  -563.022967   652.657464   -423.604535  -124.182624  1103.745413
# 1990 -4773.825237  9320.600227   3811.221481  -520.902114  2790.330374
# 1991 -2511.372919  -438.452822  10236.713157  7249.991832   710.728606
# 1992   -69.315708   -38.953246    -48.335512   -15.685238    -1.095688
#
# [1993 rows x 10 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Perform SVD on the data
U, s, Vt = np.linalg.svd(acs_pca_scaled)

# Calculate the explained variance by each principal component
explained_variance = (s ** 2) / (len(s) - 1)
explained_variance = explained_variance[4:]
# Plot the scree plot
plt.plot(range(5, len(s)+1), explained_variance, 'bo-', linewidth=2)
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.title('Scree Plot')
plt.show()
