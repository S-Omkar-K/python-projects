# %%
# !pip install prophet
import pandas as pd
import plotly.graph_objs as go 
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
# Out:
# Requirement already satisfied: prophet in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (1.5.3)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (1.1.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: holidays>=0.14.2 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (0.23)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: hijri-converter in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (2.2.4)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2022.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)

# %%
import censusdata
import numpy as np

# %%
# !pip install censusdata
# Out:
# Requirement already satisfied: censusdata in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (1.15.post1)
# Requirement already satisfied: requests in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from censusdata) (2.28.1)
# Requirement already satisfied: pandas in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from censusdata) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from pandas->censusdata) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from pandas->censusdata) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from pandas->censusdata) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from requests->censusdata) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from requests->censusdata) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from requests->censusdata) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from requests->censusdata) (1.26.14)
# Requirement already satisfied: six>=1.5 in c:\users\saiomkark\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->censusdata) (1.16.0)

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# **Atlanta Data**

# %%
counties = {'13':['013','015','035','045', '057', '063' , '067', '077', '085', '089', '097', '113', '117',
                 '121', '135', '143', '149', '151', '159', '171', '199', '211', '217', '223', '227', '231',
                 '247', '255', '297']}
states = {'13':'GA'}

# %%
def local_census_data(year,state,county):
    atlanta_county = censusdata.download('acs5', year,
                                 censusdata.censusgeo([('state', state), ('county', county), ('tract', '*')]),
                                 ['B01003_001E','B06009_005E','B06009_006E','B25001_001E','B25002_002E','B25002_003E',
                                  'B25003_002E', 'B25003_003E', 'B19013_001E'])
    atlanta_county = atlanta_county.reset_index()
    atlanta_county = atlanta_county.rename(columns={
        'index': 'Census Tract Code',
        'B01003_001E': 'Total Population',
        'B06009_005E': 'Bachelor degree',
        'B06009_006E': 'Graduate or Professional Degree',
        'B25001_001E': 'Total Housing',
        'B25002_002E': 'Total Occupied housing units',
        'B25002_003E': 'Total Vacant housing units',
        'B25003_002E': 'Total Owner occupied housing units',
        'B25003_003E': 'Total Renter occupied housing units',
        'B19013_001E': 'Median Household Income (USD)'
    })
    atlanta_county ['Bachelor degree'] = atlanta_county['Bachelor degree']+atlanta_county['Graduate or Professional Degree']
    atlanta_county['Percentage of Rent'] = atlanta_county['Total Renter occupied housing units']/atlanta_county['Total Housing']
    atlanta_county['Census Tract Code'] = atlanta_county['Census Tract Code'].astype(str)
    atlanta_county['Census Tract Code'] = atlanta_county['Census Tract Code'].apply(lambda x: str(x).split(">")[-1].split(":")[1].strip() 
                                                                if isinstance(x, str) else x.tract.split(":")[-1].strip())
    atlanta_county['Year'] = year
    atlanta_county['State'] = states[state]
    atlanta_county = atlanta_county.sort_values(by = ['Census Tract Code'], ignore_index = True)
    return atlanta_county

# %%
# Concatenate
atlanta_all = pd.DataFrame()
for year in range(2010, 2020):
    for state in counties.keys():
        for county in counties[state]:
            atlanta_county = local_census_data(year,state, county)
            atlanta_all = pd.concat([atlanta_all, atlanta_county], ignore_index=True)

# %%
atlanta_all.head()
# Out:
#   Census Tract Code  Total Population  Bachelor degree  \
# 0            180103              3350              502
# 1            180104              2138              157
# 2            180105              3242              219
# 3            180106              2787              204
# 4            180107              4025              160
#
#    Graduate or Professional Degree  Total Housing  \
# 0                              128           1333
# 1                               71            829
# 2                               33           1053
# 3                               31           1176
# 4                               43           1683
#
#    Total Occupied housing units  Total Vacant housing units  \
# 0                          1101                         232
# 1                           749                          80
# 2                          1017                          36
# 3                          1055                         121
# 4                          1472                         211
#
#    Total Owner occupied housing units  Total Renter occupied housing units  \
# 0                                 989                                  112
# 1                                 624                                  125
# 2                                 933                                   84
# 3                                 973                                   82
# 4                                 891                                  581
#
#    Median Household Income (USD)  Percentage of Rent  Year State
# 0                        67566.0            0.084021  2010    GA
# 1                        45817.0            0.150784  2010    GA
# 2                        54766.0            0.079772  2010    GA
# 3                        43776.0            0.069728  2010    GA
# 4                        39130.0            0.345217  2010    GA

# %%
atlanta_all = atlanta_all.dropna()
atlanta_all = atlanta_all[atlanta_all['Median Household Income (USD)'] != -666666666.0]

# %%
#atlanta_all = atlanta_all.drop(['Bachelor degree','Graduate or Professional Degree'], axis=1)

# %% [markdown]
# # Transform Census Tract to Zip code

# %%
zip_tract = pd.read_excel('TRACT_ZIP_122021.xlsx')
zip_tract['tract'] = zip_tract['tract'].apply(lambda x: str(x)[-6:])
zip_tract = zip_tract.rename(columns={'tract': "Census Tract Code", 'usps_zip_pref_state':'State'})
merged_df = pd.merge(atlanta_all, zip_tract, on=['Census Tract Code','State'], how='left')

# %%
grouped_data = merged_df.groupby(['zip','Year']).agg({
    'Total Population': 'sum',
    'Bachelor degree': 'sum',
    'Total Housing': 'sum',
    'Total Occupied housing units': 'sum',
    'Total Vacant housing units': 'sum',
    'Total Owner occupied housing units': 'sum',
    'Total Renter occupied housing units': 'sum',
    'Median Household Income (USD)': 'mean'
}).reset_index()
grouped_data['Median Household Income (USD)'] = grouped_data['Median Household Income (USD)'].round(2)
grouped_data['Percentage of Rent'] = round(grouped_data['Total Renter occupied housing units'] / grouped_data['Total Housing'],3)

# %%
grouped_data.head()
# Out:
#      zip  Year  Total Population  Bachelor degree  Total Housing  \
# 0  30002  2010             17126             3181           7762
# 1  30002  2011             16670             3478           7740
# 2  30002  2012             16684             3633           7910
# 3  30002  2013             16935             3717           7949
# 4  30002  2014             16582             3946           7951
#
#    Total Occupied housing units  Total Vacant housing units  \
# 0                          6811                         951
# 1                          6735                        1005
# 2                          6712                        1198
# 3                          6787                        1162
# 4                          6647                        1304
#
#    Total Owner occupied housing units  Total Renter occupied housing units  \
# 0                                2807                                 4004
# 1                                2884                                 3851
# 2                                2937                                 3775
# 3                                2947                                 3840
# 4                                2851                                 3796
#
#    Median Household Income (USD)  Percentage of Rent
# 0                        39473.4               0.516
# 1                        39711.2               0.498
# 2                        40497.4               0.477
# 3                        39573.2               0.483
# 4                        38020.0               0.477

# %%
#grouped_data.to_csv('2010-2019_Atlanta_ACS_yearly.csv', index=False)

# %%
grouped_data.to_csv('Y_AT_ACS_2010-2019.csv', index=False)

# %% [markdown]
# # Performed Linear Interpolation

# %%
## Create DF
df = (pd
        .DataFrame( index= pd.date_range( '2010-01-01', '2019-12-31' ,freq='MS'))
      .reset_index()
      .rename(columns={'index' : 'y_dt'})
      .assign(key=1)
     )

## load data
df_to_merge = grouped_data
df_census_tract = df_to_merge.loc[:, ['zip']].drop_duplicates().assign(key=1)
df = pd.merge( df, df_census_tract, how='outer', on='key').drop(['key'], axis=1)

# %%
df
# Out:
#             y_dt    zip
# 0     2010-01-01  30002
# 1     2010-01-01  30003
# 2     2010-01-01  30004
# 3     2010-01-01  30005
# 4     2010-01-01  30006
# ...          ...    ...
# 89755 2019-12-01  39867
# 89756 2019-12-01  39870
# 89757 2019-12-01  39877
# 89758 2019-12-01  39897
# 89759 2019-12-01  39901
#
# [89760 rows x 2 columns]

# %%
df_to_merge
# Out:
#         zip  Year  Total Population  Bachelor degree  Total Housing  \
# 0     30002  2010             17126             3181           7762
# 1     30002  2011             16670             3478           7740
# 2     30002  2012             16684             3633           7910
# 3     30002  2013             16935             3717           7949
# 4     30002  2014             16582             3946           7951
# ...     ...   ...               ...              ...            ...
# 7475  39901  2015              4005               53           1178
# 7476  39901  2016              3451               63           1041
# 7477  39901  2017              3555               62            928
# 7478  39901  2018              3308               71            898
# 7479  39901  2019              3002               72            857
#
#       Total Occupied housing units  Total Vacant housing units  \
# 0                             6811                         951
# 1                             6735                        1005
# 2                             6712                        1198
# 3                             6787                        1162
# 4                             6647                        1304
# ...                            ...                         ...
# 7475                          1026                         152
# 7476                           918                         123
# 7477                           843                          85
# 7478                           814                          84
# 7479                           780                          77
#
#       Total Owner occupied housing units  Total Renter occupied housing units  \
# 0                                   2807                                 4004
# 1                                   2884                                 3851
# 2                                   2937                                 3775
# 3                                   2947                                 3840
# 4                                   2851                                 3796
# ...                                  ...                                  ...
# 7475                                  56                                  970
# 7476                                  22                                  896
# 7477                                   0                                  843
# 7478                                   0                                  814
# 7479                                   0                                  780
#
#       Median Household Income (USD)  Percentage of Rent
# 0                           39473.4               0.516
# 1                           39711.2               0.498
# 2                           40497.4               0.477
# 3                           39573.2               0.483
# 4                           38020.0               0.477
# ...                             ...                 ...
# 7475                        25034.0               0.823
# 7476                        25000.0               0.861
# 7477                        26523.0               0.908
# 7478                        26630.0               0.906
# 7479                        28242.0               0.910
#
# [7480 rows x 11 columns]

# %%
assert df_to_merge.shape[0] == df_to_merge.loc[:, ['zip', 'Year']].drop_duplicates().shape[0]

## Deal with assert
df_to_merge.loc[:, 'y_dt'] = pd.to_datetime(df_to_merge['Year'], format='%Y')
df_to_merge = df_to_merge.sort_values('y_dt')

df_to_merge.head()
merged_df = pd.merge( df, df_to_merge, how='left', on = ['y_dt', 'zip'])

# %%
merged_df
# Out:
#             y_dt    zip    Year  Total Population  Bachelor degree  \
# 0     2010-01-01  30002  2010.0           17126.0           3181.0
# 1     2010-01-01  30003  2010.0            6170.0            503.0
# 2     2010-01-01  30004  2010.0           99984.0          35832.0
# 3     2010-01-01  30005  2010.0           66991.0          27351.0
# 4     2010-01-01  30006  2010.0            4251.0           1887.0
# ...          ...    ...     ...               ...              ...
# 89755 2019-12-01  39867     NaN               NaN              NaN
# 89756 2019-12-01  39870     NaN               NaN              NaN
# 89757 2019-12-01  39877     NaN               NaN              NaN
# 89758 2019-12-01  39897     NaN               NaN              NaN
# 89759 2019-12-01  39901     NaN               NaN              NaN
#
#        Total Housing  Total Occupied housing units  \
# 0             7762.0                        6811.0
# 1             2506.0                        2048.0
# 2            38664.0                       35491.0
# 3            24120.0                       22715.0
# 4             2697.0                        2288.0
# ...              ...                           ...
# 89755            NaN                           NaN
# 89756            NaN                           NaN
# 89757            NaN                           NaN
# 89758            NaN                           NaN
# 89759            NaN                           NaN
#
#        Total Vacant housing units  Total Owner occupied housing units  \
# 0                           951.0                              2807.0
# 1                           458.0                               569.0
# 2                          3173.0                             28928.0
# 3                          1405.0                             17408.0
# 4                           409.0                               196.0
# ...                           ...                                 ...
# 89755                         NaN                                 NaN
# 89756                         NaN                                 NaN
# 89757                         NaN                                 NaN
# 89758                         NaN                                 NaN
# 89759                         NaN                                 NaN
#
#        Total Renter occupied housing units  Median Household Income (USD)  \
# 0                                   4004.0                       39473.40
# 1                                   1479.0                       36187.00
# 2                                   6563.0                      105401.19
# 3                                   5307.0                      106472.92
# 4                                   2092.0                       53074.00
# ...                                    ...                            ...
# 89755                                  NaN                            NaN
# 89756                                  NaN                            NaN
# 89757                                  NaN                            NaN
# 89758                                  NaN                            NaN
# 89759                                  NaN                            NaN
#
#        Percentage of Rent
# 0                   0.516
# 1                   0.590
# 2                   0.170
# 3                   0.220
# 4                   0.776
# ...                   ...
# 89755                 NaN
# 89756                 NaN
# 89757                 NaN
# 89758                 NaN
# 89759                 NaN
#
# [89760 rows x 12 columns]

# %%
merged_df = merged_df.sort_values(['zip', 'y_dt'])

new_df = merged_df.copy()
new_df.loc[:, 'new_col'] = np.nan
new_df
# Out:
#             y_dt    zip    Year  Total Population  Bachelor degree  \
# 0     2010-01-01  30002  2010.0           17126.0           3181.0
# 748   2010-02-01  30002     NaN               NaN              NaN
# 1496  2010-03-01  30002     NaN               NaN              NaN
# 2244  2010-04-01  30002     NaN               NaN              NaN
# 2992  2010-05-01  30002     NaN               NaN              NaN
# ...          ...    ...     ...               ...              ...
# 86767 2019-08-01  39901     NaN               NaN              NaN
# 87515 2019-09-01  39901     NaN               NaN              NaN
# 88263 2019-10-01  39901     NaN               NaN              NaN
# 89011 2019-11-01  39901     NaN               NaN              NaN
# 89759 2019-12-01  39901     NaN               NaN              NaN
#
#        Total Housing  Total Occupied housing units  \
# 0             7762.0                        6811.0
# 748              NaN                           NaN
# 1496             NaN                           NaN
# 2244             NaN                           NaN
# 2992             NaN                           NaN
# ...              ...                           ...
# 86767            NaN                           NaN
# 87515            NaN                           NaN
# 88263            NaN                           NaN
# 89011            NaN                           NaN
# 89759            NaN                           NaN
#
#        Total Vacant housing units  Total Owner occupied housing units  \
# 0                           951.0                              2807.0
# 748                           NaN                                 NaN
# 1496                          NaN                                 NaN
# 2244                          NaN                                 NaN
# 2992                          NaN                                 NaN
# ...                           ...                                 ...
# 86767                         NaN                                 NaN
# 87515                         NaN                                 NaN
# 88263                         NaN                                 NaN
# 89011                         NaN                                 NaN
# 89759                         NaN                                 NaN
#
#        Total Renter occupied housing units  Median Household Income (USD)  \
# 0                                   4004.0                        39473.4
# 748                                    NaN                            NaN
# 1496                                   NaN                            NaN
# 2244                                   NaN                            NaN
# 2992                                   NaN                            NaN
# ...                                    ...                            ...
# 86767                                  NaN                            NaN
# 87515                                  NaN                            NaN
# 88263                                  NaN                            NaN
# 89011                                  NaN                            NaN
# 89759                                  NaN                            NaN
#
#        Percentage of Rent  new_col
# 0                   0.516      NaN
# 748                   NaN      NaN
# 1496                  NaN      NaN
# 2244                  NaN      NaN
# 2992                  NaN      NaN
# ...                   ...      ...
# 86767                 NaN      NaN
# 87515                 NaN      NaN
# 88263                 NaN      NaN
# 89011                 NaN      NaN
# 89759                 NaN      NaN
#
# [89760 rows x 13 columns]

# %%
for census_tract in merged_df.loc[:, 'zip'].unique():

    merged_df = merged_df.sort_values(['zip', 'y_dt'])

    for col in ['Total Population', 'Bachelor degree', 'Total Housing', 'Total Occupied housing units', 
                'Total Vacant housing units', 'Total Owner occupied housing units',
                'Total Renter occupied housing units', 'Median Household Income (USD)']:

        temp_df = (merged_df.loc[(merged_df.loc[:, 'zip'] == census_tract), [col]]
                    .interpolate(method = "spline", order = 2,  limit_direction = "both",  downcast = "infer")
                    .interpolate(method='bfill')
                    .reset_index(drop=True))

        new_df.loc[(new_df.loc[:, 'zip'] == census_tract), f'Monthly {col}'] = temp_df.values
# Out:
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# ...
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\saiomkark\AppData\Local\anaconda3\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)

# %%
temp_df
# Out:
#      Median Household Income (USD)
# 0                     26584.000000
# 1                     27145.175642
# 2                     27660.475561
# 3                     28130.215953
# 4                     28554.396818
# ..                             ...
# 115                   30140.798853
# 116                   30469.745731
# 117                   30813.111456
# 118                   31170.896027
# 119                   31543.099444
#
# [120 rows x 1 columns]

# %%
new_df
# Out:
#             y_dt    zip    Year  Total Population  Bachelor degree  \
# 0     2010-01-01  30002  2010.0           17126.0           3181.0
# 748   2010-02-01  30002     NaN               NaN              NaN
# 1496  2010-03-01  30002     NaN               NaN              NaN
# 2244  2010-04-01  30002     NaN               NaN              NaN
# 2992  2010-05-01  30002     NaN               NaN              NaN
# ...          ...    ...     ...               ...              ...
# 86767 2019-08-01  39901     NaN               NaN              NaN
# 87515 2019-09-01  39901     NaN               NaN              NaN
# 88263 2019-10-01  39901     NaN               NaN              NaN
# 89011 2019-11-01  39901     NaN               NaN              NaN
# 89759 2019-12-01  39901     NaN               NaN              NaN
#
#        Total Housing  Total Occupied housing units  \
# 0             7762.0                        6811.0
# 748              NaN                           NaN
# 1496             NaN                           NaN
# 2244             NaN                           NaN
# 2992             NaN                           NaN
# ...              ...                           ...
# 86767            NaN                           NaN
# 87515            NaN                           NaN
# 88263            NaN                           NaN
# 89011            NaN                           NaN
# 89759            NaN                           NaN
#
#        Total Vacant housing units  Total Owner occupied housing units  \
# 0                           951.0                              2807.0
# 748                           NaN                                 NaN
# 1496                          NaN                                 NaN
# 2244                          NaN                                 NaN
# 2992                          NaN                                 NaN
# ...                           ...                                 ...
# 86767                         NaN                                 NaN
# 87515                         NaN                                 NaN
# 88263                         NaN                                 NaN
# 89011                         NaN                                 NaN
# 89759                         NaN                                 NaN
#
#        Total Renter occupied housing units  ...  Percentage of Rent  new_col  \
# 0                                   4004.0  ...               0.516      NaN
# 748                                    NaN  ...                 NaN      NaN
# 1496                                   NaN  ...                 NaN      NaN
# 2244                                   NaN  ...                 NaN      NaN
# 2992                                   NaN  ...                 NaN      NaN
# ...                                    ...  ...                 ...      ...
# 86767                                  NaN  ...                 NaN      NaN
# 87515                                  NaN  ...                 NaN      NaN
# 88263                                  NaN  ...                 NaN      NaN
# 89011                                  NaN  ...                 NaN      NaN
# 89759                                  NaN  ...                 NaN      NaN
#
#        Monthly Total Population  Monthly Bachelor degree  \
# 0                  17126.000000              3181.000000
# 748                17069.654850              3211.409659
# 1496               17016.622045              3240.800468
# 2244               16966.924859              3269.163093
# 2992               16920.563292              3296.497534
# ...                         ...                      ...
# 86767               2831.904433                46.414062
# 87515               2808.168377                41.177971
# 88263               2784.568194                35.547254
# 89011               2761.103885                29.521913
# 89759               2737.775450                23.101947
#
#        Monthly Total Housing  Monthly Total Occupied housing units  \
# 0                7762.000000                           6811.000000
# 748              7750.640294                           6803.310751
# 1496             7741.141174                           6795.809981
# 2244             7733.357285                           6788.560613
# 2992             7727.288626                           6781.562645
# ...                      ...                                   ...
# 86767             765.825513                            736.290588
# 87515             748.703304                            728.542324
# 88263             730.561494                            720.424381
# 89011             711.400083                            711.936760
# 89759             691.219070                            703.079460
#
#        Monthly Total Vacant housing units  \
# 0                              951.000000
# 748                            947.362102
# 1496                           945.407496
# 2244                           944.909493
# 2992                           945.868093
# ...                                   ...
# 86767                           69.455016
# 87515                           68.082193
# 88263                           66.643768
# 89011                           65.139743
# 89759                           63.570117
#
#        Monthly Total Owner occupied housing units  \
# 0                                     2807.000000
# 748                                   2814.298199
# 1496                                  2821.427718
# 2244                                  2828.397144
# 2992                                  2835.206479
# ...                                           ...
# 86767                                   -1.323964
# 87515                                   -1.613387
# 88263                                   -1.925796
# 89011                                   -2.261192
# 89759                                   -2.619574
#
#        Monthly Total Renter occupied housing units  \
# 0                                      4004.000000
# 748                                    3988.305814
# 1496                                   3972.908870
# 2244                                   3958.075615
# 2992                                   3943.806047
# ...                                            ...
# 86767                                   756.106956
# 87515                                   752.434080
# 88263                                   748.697863
# 89011                                   744.898308
# 89759                                   741.035414
#
#        Monthly Median Household Income (USD)
# 0                               39473.400000
# 748                             39456.888558
# 1496                            39447.126703
# 2244                            39443.950773
# 2992                            39447.360769
# ...                                      ...
# 86767                           30140.798853
# 87515                           30469.745731
# 88263                           30813.111456
# 89011                           31170.896027
# 89759                           31543.099444
#
# [89760 rows x 21 columns]

# %%
new_df = new_df.drop(columns=['new_col','Year', 'Total Population','Bachelor degree','Total Housing',
                              'Total Occupied housing units', 'Total Vacant housing units',
                              'Total Owner occupied housing units',
                'Total Renter occupied housing units','Median Household Income (USD)','Percentage of Rent'])
#new_df = new_df.drop(columns=['Total Occupied housing units', 'Total Vacant housing units'])
new_df.iloc[:, 2:10] = new_df.iloc[:, 2:10].astype(int)
new_df['Monthly Percentage of Rent'] = new_df['Monthly Total Renter occupied housing units']/new_df['Monthly Total Housing']
# Out:
# C:\Users\saiomkark\AppData\Local\Temp\ipykernel_13696\1241240472.py:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   new_df.iloc[:, 2:10] = new_df.iloc[:, 2:10].astype(int)

# %%
new_df.head()
# Out:
#            y_dt    zip  Monthly Total Population  Monthly Bachelor degree  \
# 0    2010-01-01  30002                     17126                     3181
# 748  2010-02-01  30002                     17069                     3211
# 1496 2010-03-01  30002                     17016                     3240
# 2244 2010-04-01  30002                     16966                     3269
# 2992 2010-05-01  30002                     16920                     3296
#
#       Monthly Total Housing  Monthly Total Occupied housing units  \
# 0                      7762                                  6811
# 748                    7750                                  6803
# 1496                   7741                                  6795
# 2244                   7733                                  6788
# 2992                   7727                                  6781
#
#       Monthly Total Vacant housing units  \
# 0                                    951
# 748                                  947
# 1496                                 945
# 2244                                 944
# 2992                                 945
#
#       Monthly Total Owner occupied housing units  \
# 0                                           2807
# 748                                         2814
# 1496                                        2821
# 2244                                        2828
# 2992                                        2835
#
#       Monthly Total Renter occupied housing units  \
# 0                                            4004
# 748                                          3988
# 1496                                         3972
# 2244                                         3958
# 2992                                         3943
#
#       Monthly Median Household Income (USD)  Monthly Percentage of Rent
# 0                                     39473                    0.515846
# 748                                   39456                    0.514581
# 1496                                  39447                    0.513112
# 2244                                  39443                    0.511832
# 2992                                  39447                    0.510289

# %%
new_df['Bachelor or higher Precentage'] = new_df['Monthly Bachelor degree'] / new_df['Monthly Total Population']

# %%
new_df.head(10)
# Out:
#            y_dt    zip  Monthly Total Population  Monthly Bachelor degree  \
# 0    2010-01-01  30002                     17126                     3181
# 748  2010-02-01  30002                     17069                     3211
# 1496 2010-03-01  30002                     17016                     3240
# 2244 2010-04-01  30002                     16966                     3269
# 2992 2010-05-01  30002                     16920                     3296
# 3740 2010-06-01  30002                     16877                     3322
# 4488 2010-07-01  30002                     16837                     3348
# 5236 2010-08-01  30002                     16801                     3372
# 5984 2010-09-01  30002                     16768                     3395
# 6732 2010-10-01  30002                     16738                     3417
#
#       Monthly Total Housing  Monthly Total Occupied housing units  \
# 0                      7762                                  6811
# 748                    7750                                  6803
# 1496                   7741                                  6795
# 2244                   7733                                  6788
# 2992                   7727                                  6781
# 3740                   7722                                  6774
# 4488                   7720                                  6768
# 5236                   7719                                  6762
# 5984                   7720                                  6756
# 6732                   7722                                  6750
#
#       Monthly Total Vacant housing units  \
# 0                                    951
# 748                                  947
# 1496                                 945
# 2244                                 944
# 2992                                 945
# 3740                                 948
# 4488                                 952
# 5236                                 957
# 5984                                 964
# 6732                                 972
#
#       Monthly Total Owner occupied housing units  \
# 0                                           2807
# 748                                         2814
# 1496                                        2821
# 2244                                        2828
# 2992                                        2835
# 3740                                        2841
# 4488                                        2848
# 5236                                        2854
# 5984                                        2860
# 6732                                        2866
#
#       Monthly Total Renter occupied housing units  \
# 0                                            4004
# 748                                          3988
# 1496                                         3972
# 2244                                         3958
# 2992                                         3943
# 3740                                         3930
# 4488                                         3916
# 5236                                         3904
# 5984                                         3892
# 6732                                         3880
#
#       Monthly Median Household Income (USD)  Monthly Percentage of Rent  \
# 0                                     39473                    0.515846
# 748                                   39456                    0.514581
# 1496                                  39447                    0.513112
# 2244                                  39443                    0.511832
# 2992                                  39447                    0.510289
# 3740                                  39457                    0.508936
# 4488                                  39473                    0.507254
# 5236                                  39497                    0.505765
# 5984                                  39526                    0.504145
# 6732                                  39563                    0.502461
#
#       Bachelor or higher Precentage
# 0                          0.185741
# 748                        0.188119
# 1496                       0.190409
# 2244                       0.192679
# 2992                       0.194799
# 3740                       0.196836
# 4488                       0.198848
# 5236                       0.200702
# 5984                       0.202469
# 6732                       0.204146

# %%
new_df.to_csv('2010-2019_Atlanta_ACS_monthly.csv', index=False)

# %%
new_df.to_csv('M_AT_ACS_2010-2019.csv', index=False)
